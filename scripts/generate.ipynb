15 00 11 00 15 04 13 02 61 02 63 04 65 00 64 03 72 00 73 00 24 00 25 00 67 08 65 04 65 00 64 05 77 08 75 04 75 00 74 05 14 03 12 0e 11 00 1e 01 12 03 14 05 11 00 15 07 67 08 65 04 65 00 64 05 77 08 75 04 75 00 74 05 14 03 12 0e 11 00 1e 01 12 03 14 05 11 00 15 07 67 08 65 04 65 00 64 05 77 08 75 04 75 00 74 05 14 03 12 0e 11 00 1e 01 12 03 14 05 11 00 15 07 67 08 65 04 65 00 64 05 77 08 75 04 75 00 74 05 1a 09 18 07 15 00 14 05 14 03 12 0e 11 00 00 00 67 08 65 04 65 00 64 05 77 08 75 04 75 00 74 05 14 03 12 0e 11 00 1e 01 12 03 14 05 11 00 15 07 67 08 65 04 65 00 64 05 77 08 75 04 75 00 74 05 14 03 12 0e 11 00 1e 01 12 03 14 05 11 00 15 07 67 08 65 04 65 00 64 05 77 08 75 04 75 00 74 05 14 03 12 0e 11 00 1e 01 12 03 14 05 11 00 15 07 67 08 65 04 65 00 64 05 77 08 75 04 75 00 74 05 1a 09 18 07 15 00 14 05 14 03 12 0e 11 00 00 00"

# %%
mapping = {
    'f': 'fruit',
    'e': 'egg',
    'd': 'drink',
    'c': 'cake',
    'b': 'bottle',
    'a': 'algae',
    '9': 'cat',
    '8': 'cog',
    '7': 'cash',
    '6': 'sax',
    '5': 'hand',
    '4': 'dust',
    '3': 'bubble',
    '2': 'scissors',
    '1': 'stick',
    '0': 'donut',
}

i = 0
for note in song.split():
    print(f'object {i} 0 {mapping[note[0]]} right')
    print(f'object {i} 3 {mapping[note[1]]} right')
    i += 1
# Out:
# object 0 0 donut right
# object 0 3 donut right
# object 1 0 donut right
# object 1 3 donut right
# object 2 0 donut right
# object 2 3 donut right
# object 3 0 donut right
# object 3 3 donut right
# object 4 0 donut right
# object 4 3 donut right
# object 5 0 donut right
# object 5 3 donut right
# object 6 0 donut right
# object 6 3 donut right
# object 7 0 donut right
# object 7 3 donut right
# object 8 0 donut right
# object 8 3 donut right
# object 9 0 donut right
# object 9 3 donut right
# object 10 0 donut right
# object 10 3 donut right
# object 11 0 donut right
# object 11 3 donut right
# object 12 0 donut right
# object 12 3 donut right
# object 13 0 donut right
# object 13 3 donut right
# object 14 0 donut right
# object 14 3 donut right
# object 15 0 donut right
# object 15 3 donut right
# object 16 0 donut right
# object 16 3 donut right
# object 17 0 donut right
# object 17 3 donut right
# object 18 0 donut right
# object 18 3 donut right
# object 19 0 donut right
# ...
